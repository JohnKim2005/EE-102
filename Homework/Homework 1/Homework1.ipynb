# %% [markdown]
# Min Je (John) Kim
# FA25 EE 102
# Homework 1 : Signals
# 9/07/2025

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %%
# Problem 3 Signal A
n = np.linspace(0, 5, 200)
x = (1/3)**n



plt.plot(n, x, label = "x [n]")
plt.xlabel("n")
plt.ylabel("x")
plt.title("x[n] = (1/3)^n * u[n]")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Problem 3 Signal B
t = np.linspace(-4,4, 500)
x2_real = np.cos(3*t + np.pi/7)
x2_imag = np.sin(3*t + np.pi/7)


plt.plot(t, x2_real, label="Real part")
plt.plot(t, x2_imag, label="Imag part")
plt.title("x2(t) = e^( j * (3t + π/7) )")
plt.xlabel("t")
plt.ylabel("Amplitude")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Problem 3 Signal C
n = np.linspace(0, 12, 500)
x3_real = np.cos(np.pi*n/3 + np.pi/7)
x3_imag = np.sin(np.pi*n/3 + np.pi/7)



plt.plot(n, x3_real, label = "Real part")
plt.plot(n, x3_imag, label = "Imag part")
plt.xlabel("n")
plt.ylabel("Amplitude")
plt.title("x[n] = e^( j * (n*pi/3 + pi/10) )")
plt.legend()
plt.grid(True)
plt.show()
